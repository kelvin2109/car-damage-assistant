# %%
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as image
import json
import numpy as np
import os
import pandas as pd
import plotly.express as px 
import math

# %% [markdown]
# # Load and Inspect Dataset

# %%
with open("data/annotations/instances_train.json","r") as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['licenses', 'info', 'categories', 'images', 'annotations'])

# %% [markdown]
# # EDA and Feature Engineering

# %%
for k, v in data.items():
    
    if isinstance(v, list):
        print(f"\nType: {type(v).__name__}")
        print(f"{k}:{len(v)} items")
        if len(v)>0:
            print("first-element:",v[0])
            
    elif isinstance(v, dict):
        print(f"\nType: {type(v).__name__}")
        print(f"{k}: {len(v)}")
        print(f"Dict with {len(v.keys())}keys:{v}")
        
    else:
        print()
# Out:
# Type: list
# licenses:1 items
# first-element: {'name': 'CarDD', 'id': 0, 'url': 'https://cardd-ustc.github.io/'}
#
# Type: dict
# info: 5
# Dict with 5keys:{'contributor': 'Xinkuang Wang, Wenjing Li, Zhongcheng Wu', 'date_created': '2022.05.01', 'description': 'CarDD for car damage detection in COCO Format.', 'url': 'https://cardd-ustc.github.io/', 'version': 'v1.0'}
#
# Type: list
# categories:6 items
# first-element: {'id': 1, 'name': 'dent'}
#
# Type: list
# images:2816 items
# first-element: {'id': 1, 'width': 1000, 'height': 750, 'file_name': '000001.jpg', 'license': 0}
#
# Type: list
# annotations:6211 items
# ...

# %% [markdown]
# ## **Conclusion**
# The dataset contains five main keys: **licenses**, **info**, **categories**, **images**, and **annotations**.
# For car damage detection, the **important components** are `images`, `annotations`, and `categories`.
# - `annotations` provide bounding boxes (`bbox`) and category IDs — essential for training.
# - `segmentation` and `attributes` inside `annotations` are **not required** unless we do segmentation tasks.
# - `licenses` and `info` are **metadata only**, not used for model training.
#
# Additional dataset characteristics:
# - Image resolutions are generally consistent (e.g., around **1000×750**), providing enough detail for detection.
# - With **2,816 images** and **6,211 annotations**, each image contains on average **~2 damage instances**.

# %%
def clean_annotations(data):
    
    #path for input annotation-file
    input_path = "data/annotations/instances_train.json"
    #path for cleaned annotation-folder
    cleaned_dir = "data/annotations/cleaned/"
    clean_file_name = "annotations_train_cleaned.json"
    #Create folder if it doesn’t exist
    os.makedirs(cleaned_dir,exist_ok=True)
    #check if we already had the cleaned annotation file'
    print(os.path.join(cleaned_dir,clean_file_name))
    if os.path.exists(os.path.join(cleaned_dir,clean_file_name)):
        print("The cleaned file already exist.")
        
        with open(os.path.join(cleaned_dir,clean_file_name),"r") as f:
            data= json.load(f)
    
    else:
        with open(input_path,"r") as f:
            data = json.load(f)
        
        #Remove unnecessary meta-data
        keys = ["licenses","info"]
        for key in keys:
            if key in data:
                del data[key]
                print(f"{key} successfully deleted!")
                
        #Remove unnecessary annotation-field
        fields_to_remove = ["segmentation","attributes"]
        for del_ in fields_to_remove:
            deleted = False
            for anno in data["annotations"]:
                if del_ in anno:
                    anno.pop(del_,None)
                    deleted = True
            if(deleted):
                print(f"{del_} successfully deleted!")
                
        with open(os.path.join(cleaned_dir,clean_file_name),"w") as f:
            json.dump(data,f,indent = 2)
            
        print(f"Cleaned file saved at {os.path.join(cleaned_dir,clean_file_name)}")
                    
    return data

# %%
data = clean_annotations(data)
# Out:
# data/annotations/cleaned/annotations_train_cleaned.json
# The cleaned file already exist.

# %%
with open("annotations_cleaned.json","w") as f:
    json.dump(data,f,indent=4)

# %%
# Convert JSON categories and annotations to DataFrames
df_cat = pd.DataFrame(data["categories"])
df_ann = pd.DataFrame(data["annotations"])
# Count number of annotations per category
counts = df_ann["category_id"].value_counts().reset_index()
# Merge annotation counts per category with category names for easier analysis
merged_df = pd.merge(df_cat, counts, left_on='id', right_on='category_id', how='inner')

# %%
merged_df
# Out:
#    id           name  category_id  count
# 0   1           dent            1   1806
# 1   2        scratch            2   2560
# 2   3          crack            3    651
# 3   4  glass shatter            4    475
# 4   5    lamp broken            5    494
# 5   6      tire flat            6    225

# %%
# Create a donut chart to visualize the distribution of images per class
fig = px.pie(
    merged_df,
    names="name",
    values="count",
    title="Image Class Distribution (Donut Chart)",
    hole=0.4  # set 0 < hole < 1 to create a donut
)

fig.show()

# %% [markdown]
# ## Class Distribution Conclusion
#
# The dataset displays a **clear class imbalance** across the six damage categories.
# The classes **scratch (2560 samples)** and **dent (1806 samples)** are significantly more frequent than the others.
# In contrast, **tire flat (225 samples)**, **glass shatter (475 samples)**, and **lamp broken (494 samples)** have much fewer samples.
#
# This imbalance may cause the model to **bias predictions toward the common classes**, leading to **lower recall and poor mAP** for the minority classes.
#
# ### Recommended Measures
# We will address this imbalance by applying **class-weighted loss** in the **classification head of Faster R-CNN**.
# This approach increases the contribution of minority classes during training, helping the model learn to recognize them more effectively without altering the dataset itself.
#
# ### Evaluation Focus
# - Monitor **per-class mAP**, not only overall mAP, to ensure performance is balanced across all damage categories.

# %% [markdown]
# # Display Sample Images per Class

# %% [markdown]
# ## prepare dataframe for single-class image sample.

# %%
df_img = pd.DataFrame(data['images'])
df_img.head(5)
# Out:
#    id  width  height   file_name  license
# 0   1   1000     750  000001.jpg        0
# 1   2   1000     667  000002.jpg        0
# 2   3   1000     667  000003.jpg        0
# 3   4   1000     667  000004.jpg        0
# 4   5   1000     667  000005.jpg        0

# %%
# Get one unique image per category:
unique_img_per_category  = (df_ann[~df_ann.duplicated(subset=["image_id"], keep=False)]
                            .groupby("category_id").first().drop(columns=["id","iscrowd"]).reset_index()
                            .merge(df_cat,left_on="category_id",right_on="id" ).drop(columns=["id"]))

# %%
# Get the actual images corresponding to those unique image IDs
unique_img_dataset = (df_img[df_img["id"].isin(unique_img_per_category["image_id"])]
                .merge(unique_img_per_category,left_on = "id" ,right_on =  "image_id" ).drop(columns=["id","image_id","license","area"]))

# %%
unique_img_dataset
# Out:
#    width  height   file_name  category_id                              bbox  \
# 0   1000     667  000002.jpg            6   [476.73, 241.02, 397.2, 346.68]
# 1   1000     645  000019.jpg            2  [321.03, 153.39, 429.53, 386.27]
# 2   1000     667  000032.jpg            3  [301.65, 310.83, 145.55, 166.87]
# 3   1000     667  000041.jpg            4        [0.0, 0.0, 804.43, 541.07]
# 4    750    1000  000067.jpg            1  [172.14, 203.61, 296.77, 539.96]
# 5   1000     667  000077.jpg            5   [14.64, 203.76, 745.34, 307.78]
#
#             name
# 0      tire flat
# 1        scratch
# 2          crack
# 3  glass shatter
# 4           dent
# 5    lamp broken

# %% [markdown]
# ## Prepare dataframe for multi-class image sample

# %%
#Keep all duplicated annotations (images with more than one object)
duplicated_ann = df_ann[df_ann.duplicated(subset=["image_id"], keep=False)]

# %%
def select_unique_category_image_pairs(col1,col2):

    """
    Keep a row only if:
      - The category has not been used in a kept row yet, AND
      - The image has not been used in a kept row yet.

    A row is skipped if either the category or image is already used.
    When a row is skipped, we do NOT mark its category or image as used.
    This allows that category or image to still be used later if it
    appears again in a valid (both new) pairing.
    """
    
    seen1 = set()
    seen2 = set()
    mask = []
    # Skip if either category OR image has been seen at all
    for c1, c2 in zip(col1, col2):
        both_new = (c1 not in seen1) and (c2 not in seen2)
        mask.append(both_new)   
        # IMPORTANT: record BOTH category and image as seen
        if(both_new):
            seen1.add(c1)
            seen2.add(c2)
    return mask

# %%
representative_pairs = duplicated_ann[select_unique_category_image_pairs(duplicated_ann["category_id"],duplicated_ann["image_id"])].drop(columns=["id"]).reset_index(drop=True)

# %%
selected_image_ann = (df_ann[df_ann["image_id"].isin(representative_pairs["image_id"])].drop(columns=["id"])
                        .merge(df_cat,left_on = "category_id",right_on = "id").drop(columns=["id"]))

# %%
# Aggregate all categories, areas, and bounding boxes for each duplicated image
selected_image_ann_grouped = selected_image_ann.groupby("image_id").agg({'category_id':list , 'bbox':list, "name":lambda x:list(set(x)) }).reset_index()

# %%
# Merge image info with aggregated annotations for images with multiple objects
multiclass_img_dataset = (df_img[df_img["id"].isin(selected_image_ann_grouped["image_id"])].merge(selected_image_ann_grouped ,left_on='id' ,right_on='image_id' )
            .drop(columns =["image_id","id","license"]).reset_index(drop=True))

# %%
multiclass_img_dataset
# Out:
#    width  height   file_name            category_id  \
# 0   1000     750  000001.jpg                 [2, 6]
# 1   1000     678  000008.jpg  [3, 3, 3, 3, 3, 3, 6]
# 2   1000     667  000009.jpg           [1, 2, 6, 6]
# 3   1000     667  000014.jpg           [1, 2, 2, 6]
# 4   1000     667  000029.jpg              [1, 1, 5]
# 5   1000     750  000048.jpg                 [1, 4]
#
#                                                 bbox  \
# 0  [[167.04, 40.21, 202.79, 131.34], [160.66, 112...
# 1  [[308.33, 74.33, 49.41, 126.45], [388.87, 155....
# 2  [[603.25, 203.39, 93.02, 94.72], [313.14, 282....
# 3  [[610.63, 248.2, 163.34, 75.44], [752.53, 342....
# 4  [[363.34, 135.33, 365.83, 508.76], [602.69, 6....
# 5  [[769.72, 218.06, 171.56, 160.08], [208.2, 0.0...
#
#                          name
# 0        [tire flat, scratch]
# 1          [crack, tire flat]
# 2  [dent, tire flat, scratch]
# 3  [dent, tire flat, scratch]
# 4         [lamp broken, dent]
# 5       [dent, glass shatter]

# %%
def show_presentated_image_eachclass( sample_img, num_class, img_dir="data/train/", fig_size =(10,10)):

    """
    Display sample images per class with bounding boxes for EDA.

    Parameters
    ----------
    sample_img : pd.DataFrame
        DataFrame with columns ["file_name", "bbox", "name"].
    num_class : int
        Number of classes to display.
    img_dir : str
        Directory containing image files.
    color : tuple
        BGR color for bounding boxes.
    figsize : tuple
        Figure size for the plot.
    """
    
    # Convert to list of dicts for easy iteration
    sample_img = sample_img[["file_name","category_id","bbox","name"]].to_dict(orient="records")

    # Create subplot grid for showing images
    row = math.ceil(num_class/3)
    fig, axes = plt.subplots(row,3,figsize=fig_size , constrained_layout=True)
    fig.suptitle("Sample Images per Class",  fontsize=16, y=1.00)  # Move title higher
    #plt.subplots_adjust(wspace=0.1, hspace=0.3) 

    # List to store images after loading and drawing bbox
    images = []
    
    # Select 1 sample per class
    for path in sample_img:
        img = os.path.join("data/train/", path['file_name'])
        img = cv2.imread(img)
        color = (0, 255, 0)#RGB
        thickness = 2
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        if isinstance(path["category_id"], list):
            for i in path["bbox"]:
                x, y, w, h = i
                cv2.rectangle(img, (int(x), int(y)), (int(x + w), int(y + h)), color, thickness)
            images.append(img)
            
        else:
            x, y, w, h = path["bbox"]
            cv2.rectangle(img, (int(x), int(y)), (int(x + w), int(y + h)), color, thickness)
            images.append(img)
        
    # Display each image with its class title
    for i, ax in enumerate(axes.flat):
        ax.set_title("Class: {}".format(sample_img[i]["name"]), fontsize=12)
        if i < len(images):
            ax.imshow(images[i])

        ax.axis('off')

# %%
show_presentated_image_eachclass(unique_img_dataset,6)

# %%
show_presentated_image_eachclass( multiclass_img_dataset, 6)

# %% [markdown]
# # Conclusion of Visualizing Sample Images per Class
#
# To understand the dataset and validate annotation quality, we display **one representative image from each damage category** with bounding boxes. This helps ensure that:
#
# - Bounding boxes are correctly aligned with the damage.
# - Each class is properly represented in the dataset.
# - Image sizes and aspect ratios are suitable for model trai
